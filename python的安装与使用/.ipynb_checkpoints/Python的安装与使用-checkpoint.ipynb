# %% [markdown]
# # 第一步，安装Anaconda

# %% [markdown]
# 这是官网下载的地址：https://www.anaconda.com/distribution/#download-section
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 安装步骤及注意事项
# 整个步骤属于一键式安装过程，只有一个部分是需要特别注意的:
# ![image.png](attachment:image.png)

# %% [markdown]
# 因为这部分是将path自动帮你加入到系统的环境变量中，不用自己再单独的配置安装了。

# %% [markdown]
# 等安装完毕后，按win+R键，输入cmd，出现命令行，然后输入 python 出现版本信息说明就安装成功。
# ![image.png](attachment:image.png)

# %% [markdown]
# # 第二步，安装PyCharm

# %% [markdown]
# PyCharm是一个python的一个IDE，用它来编Python代码非常好用，基本上是业界标配。
# 整个安装过程更简单，百度/谷歌去搜索一下PyCharm，去官网上下载一个专业版的。如果有学生或者老师邮箱的话，可以在官网上下载一个，可以免费使用！
